# %%
import pandas
import numpy
import random
import copy
import csv
import collections
import time
import pandas as pd

# %% [markdown]
# # Defining Classes.

# %%
class Course():
  def __init__(self):
    self.course_id = 0
    self.course_code = ""
    self.course_name = ""

class Teacher():
  def __init__(self):
    self.teacher_id = 0
    self.teacher_name = ""
                                         
class Timeslot():                                      
  def __init__(self,day,time):
    # self.timeslot_id = 0 
    self.day = day
    self.time = time
  def __hash__(self):
    return hash(self.day) ^ hash(self.time)
  def __eq__(self,obj):
    return self.day == obj.day and self.time == obj.time
    
#Chromosome Class
class Timetable():
  def __init__(self,chromosome):
    self.chromosome = chromosome
  
class Student():
  def __init__(self):
    self.student_id = 0
    self.student_name = ""

#Defining timeslots, days of the week and classrooms.
slots = ["9:00-12:00","2:00-5:00"]
week = ["Monday-1","Tuesday-1","Wednesday-1","Thursday-1","Friday-1",
        "Monday-2","Tuesday-2","Wednesday-2","Thursday-2","Friday-2"
       ] 
        # "Monday-3","Tuesday-3","Wednesday-3","Thursday-3","Friday-3"]
classrooms = ["C-301","C-302","C-303","C-304","C-305","C-306","C-307","C-308","C-309","C-310"]

# %% [markdown]
# #Reading datasets.

# %%
#Reading list of courses.
courses = []

with open("courses.csv", mode = 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter = ',')
  line_count = 0
  for row in csv_reader:
    if any(obj.course_code == row[0] for obj in courses):
      continue
    course = Course()
    course.course_code = row[0]
    course.course_name = row[1]
    course.course_id = line_count
    line_count += 1
    courses.append(course)

for n in courses:
  print(n.course_id, n.course_name, n.course_code)
# Out:
# 0 Object Oriented Programming CS217
# 1 Digital Logic Design EE227
# 2 Discrete Structures CS211
# 3 Intro to Software Engineering SE110
# 4 Programming Fundamentals CS118
# 5 Database Systems CS219
# 6 Operating Systems CS220
# 7 Design & Analysis of Algorithms CS302
# 8 Digital Forensics CY2012
# 9 Computer Networks CS307
# 10 Software Engineering CS328
# 11 Computer Organization and Assembly Language EE229
# 12 Programming for AI AI2011
# 13 Big Data Analytics DS3011
# 14 Data Structures CS218
# 15 Differential Equations MT224
# 16 Pakistan Studies SS113
# 17 Marketing Management MG220
# 18 Fundamentals of Management MG223
# 19 Islamic and Religious Studies SS111
# 20 Communication & Presentation Skills SS152
# 21 Psychology SS118
# 22 Probability and Statistics MT205

# %%
#Reading list of teachers.
teachers = []

with open("teachers.csv", mode = "r") as teacher_file:
  line_count = 0
  csv_reader = csv.reader(teacher_file, delimiter = '\n')
  for row in csv_reader:
    if any(obj.teacher_name == row for obj in teachers):
      continue
    temp = ""
    for i in row:
      temp += i
    if temp is not "":
      teacher = Teacher()
      teacher.teacher_id = line_count
      teacher.teacher_name = temp
      teachers.append(teacher)
      line_count += 1

for n in teachers:
  print(n.teacher_id, n.teacher_name)
# Out:
# 0 Ayesha Bano
# 1 Aqeel Shahzad
# 2 Farah Naz
# 3 Hamda Khan
# 4 Usman Rashid
# 5 Farah Jabeen Awan
# 6 Sara Aziz
# 7 Gul e Aisha
# 8 Maimoona Rassol
# 9 Sajid Khan
# 10 Tayyab Nadeem
# 11 Mehboobullah
# 12 Muhammad bin Qasim
# 13 Zainab Moin
# 14 Sumera Abbas
# 15 Sadia Nauman
# 16 Shahzad Mehmood
# 17 Sanaa Ilyas
# 18 Nagina Safdar
# 19 Asma Nisa
# 20 Sehrish Hassan
# 21 Waqas Munir
# 22 Usman Ashraf
# 23 Muhammad Usman
# 24 Naveed Ahmad
# 25 Zainab Abaid
# 26 Rohail Gulbaz
# 27 Hassan Raza
# 28 Javaria Imtiaz
# 29 Maheen Arshad
# 30 Zohaib Iqbal
# 31 Mehreen Alam
# 32 Mehwish Hassan
# 33 Shams Farooq
# 34 Ameen Chilwan
# 35 Shafaq Riaz
# 36 Khadija Farooq
# 37 Amna Irum
# 38 Irum Inayat
# 39 Bilal Khalid
# 40 Shehreyar Rashid
# 41 Umair Arshad
# 42 Subhan Ullah
# 43 Ejaz Ahmed
# 44 Kifayat Ullah
# 45 Waseem Shahzad
# 46 Adnan Tariq
# 47 Asif Naeem
# 48 Hasan Mujtaba
# 49 Sidra Khalid
# 50 Faisal Cheema
# 51 Shoaib Mehboob
# 52 Tayyaba Zainab
# 53 Arshad Islam
# 54 Noor ul Ain
# 55 Zeeshan Qaiser
# 56 Muhammad Asim
# 57 Behjat Zuhaira
# 58 Kashif Munir
# 59 Hammad Majeed
# 60 Noreen Jamil
# 61 Hassan Mustafa
# 62 Farwa Batool

# %%
#Reading list of students.
students = []

with open("studentNames.csv", mode = 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter = ',')
  line_count = 0
  for row in csv_reader:
    if any(obj.student_name == row[0] for obj in students):
      continue
    student = Student()
    student.student_name = row[0]
    student.student_id = line_count
    line_count += 1
    students.append(student)

for n in students:
  print(n.student_id, n.student_name)
# Out:
# 0 Mohammed Azam
# 1 Mohamed F Bakaram
# 2 Manal Aldaihani
# 3 Ibrar Manawer
# 4 Adam Flowers
# 5 Lilia Kyuchukova
# 6 Sarina Patel
# 7 Aleena Unadkat
# 8 Ibrahim Adegboye
# 9 Salma Khanam
# 10 Kiran K Chahal
# 11 Omar F Khan
# 12 Seema Mandalia
# 13 Asim Ali
# 14 Yasmin Ahmed
# 15 Sheila Hughton
# 16 Sarah Taylor
# 17 Anja Sarlah
# 18 Syed M Abbas
# 19 Hanna I Siahaan
# 20 Sarah Austin
# 21 Mohammed Riyaz Shahul Hameed Mohammed Yakub
# 22 Halima Sayed
# 23 Sarah L Barber-Jones
# 24 Meryem Mehmetbasoglu
# 25 Adam L Finch
# 26 Sarah Hanley
# 27 Sarah Fogg
# 28 Tara Glickman
# 29 Reem N Hassan
# 30 Amir Ahmed
# 31 Sarah French
# 32 Sarah J Roberts
# 33 Sam D Edwards
# 34 Sam Duncanson
# 35 Amber Summerfield
# 36 Mika Tatsumoto
# 37 Maria Antonia Morua Leyva
# 38 Ann D Brix
# 39 Jina Zhao
# 40 Zahir Hussain
# 41 Syed M Ghufran
# 42 Adam C Ryan
# 43 Adam Sanders
# 44 Mohamed A Baalousha
# 152 Nosheen Maqbool
# 153 Dalia Remeikyte
# 154 Rida Shaikh
# 155 Rafal Szczypinski
# 156 Kamal Anwar
# 157 Hassana Begum
# 158 Sarah Dobson
# 159 Ann Wilson
# 160 Bushra Duri
# 161 Sarah Hinett
# 162 Eileen Haycox
# 163 Bahjat Al-Ani
# 164 Ramesh R Singh
# 165 Sarah J Hammon
# 166 Kamila Keshubay
# 167 Mohammed Z Albahar
# 168 Salman Hassan Zadeh
# 169 Razan Z Haji Zulkifli
# 170 Aras Panahian Jand
# 171 Leyla Doroudi
# 172 Sara De La Serna
# 173 Negar Saleh
# 174 Nima Dirie
# 175 Ana Sbert Ortin
# 176 Omar S Aslam
# 177 Imtiaz Kermali
# 178 Safiya Issa
# 179 Faris Quaid
# 180 Muna Osman
# 181 Farzad Farahmand
# 182 Iram Meharban
# 183 Sarah Hadley
# 184 Ahmad F Yang Abd Talib
# 185 Sarwar Hussain
# 186 Mona Vadher
# 187 Ayse Hatunoglu
# 188 Faraj B Shaban
# 189 Ayman Jaheen
# 190 Abdul Gafur
# 191 Ahmed Ahmed
# 192 Aida Hoxha
# 193 Muhammad Ijaz-Ul-Haq
# 194 Ahmed Abbas Ahmed
# 195 Naveed Hussain
# 196 Sarah L Clark
# 197 Maria Lytras
# 198 Bibi A Khan
# 199 Iram Matloob

# %%
#Saving list of courses registered against student.
student_registrations = dict()

with open("studentCourse.csv", mode = 'r') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter = ",")
  line_count = 0
  for row in csv_reader:
    if line_count == 0:
      line_count += 1
      continue
    else:
      if row[1] not in student_registrations: # Name of student.
        student_registrations[row[1]] = []
        student_registrations[row[1]].append(row[2])
      else:
        student_registrations[row[1]].append(row[2])

for key,value in student_registrations.items():
  print(key,value)
# Out:
# Sam D Edwards ['AI2011', 'SS152', 'EE229', 'CS220']
# Sheila Hughton ['DS3011', 'CS328', 'CS118', 'CS302']
# Yasmin Ahmed ['SE110', 'CS307', 'SS113', 'CY2012']
# Sarah N Md Sallehuddin Khan ['EE229', 'CS328', 'CS307', 'MG223']
# Sarah Nolasco ['AI2011', 'CS328', 'CS307', 'MG223']
# Jenna Riley ['EE229', 'CS211', 'SE110', 'MT205']
# Usman Rafiq ['CS307', 'CS218', 'CS118', 'CS302']
# Reem N Hassan ['MG220', 'SS118', 'SS152', 'MT224']
# Sarah Hinett ['CS328', 'CS217', 'CS307', 'SS152']
# Kamal Anwar ['EE229', 'MG220', 'SS152', 'MT205']
# Mika Tatsumoto ['CS219', 'CS217', 'CS118', 'CS218']
# Muhammad Ijaz-Ul-Haq ['AI2011', 'CS211', 'SS113', 'EE229']
# Abdul Gafur ['SS118', 'SE110', 'DS3011', 'CS217', 'CS328']
# Ana Vukojevic ['CS307', 'AI2011', 'SS152', 'SS113']
# Arooba Zahoor ['CS302', 'SS113', 'AI2011', 'MT205']
# Ahmad F Yang Abd Talib ['MG223', 'CS307', 'CS211', 'CS218']
# Natasha Leeson ['CS328', 'SS113', 'CS307', 'CS211', 'SS152']
# Ramesh R Singh ['MG220', 'MT224', 'MG223', 'CS220']
# Sara Zamberlan ['CS211', 'CS217', 'CS307', 'AI2011']
# Adam N Starling ['CS217', 'EE227', 'CS211', 'SS118']
# Maria M Ponce Carpio ['EE229', 'SS113', 'EE227', 'SS111']
# Iram Matloob ['MT224', 'CS220', 'MG220', 'DS3011']
# Sarah J Roberts ['SS152', 'CS307', 'MG223', 'EE229']
# Maria Lytras ['CS307', 'MG220', 'CS218', 'AI2011']
# Mohammad Abir ['CS218', 'MT205', 'MT224', 'CS211', 'MG223']
# Nabila Altaf ['CS211', 'MT224', 'EE229', 'MG223']
# Maria A Grenfell ['MT205', 'CS220', 'EE227', 'SS118']
# Mohamed A Baalousha ['MG220', 'MG223', 'CS307', 'SS113']
# Ayan Lowe ['SE110', 'CS307', 'SS152', 'CS220', 'MT205']
# Mohammed I Al Arfaj ['SS152', 'SE110', 'CS211', 'MT205']
# Mohammed Riyaz Shahul Hameed Mohammed Yakub ['MG223', 'CY2012', 'CS328', 'EE227']
# Sarah Armstrong ['SS111', 'SS152', 'CS217', 'CS220', 'CS307']
# Parastoo Jamshidi ['DS3011', 'SS111', 'MG220', 'CS217']
# Safiya Issa ['CS328', 'AI2011', 'CS211', 'CS218']
# Muna Osman ['MG220', 'AI2011', 'EE227', 'CS328', 'DS3011']
# Adam L Finch ['SE110', 'CS211', 'SS113', 'CS307']
# Hanna I Siahaan ['SS152', 'DS3011', 'SS113', 'CS218']
# Anja Brezovnik ['SS113', 'EE229', 'CS219', 'CS302']
# Mohammed A Suleman ['SE110', 'SS113', 'SS152', 'DS3011']
# Adam Mickiewicz ['SS111', 'CS118', 'CS220', 'MG223']
# Bushra Duri ['CS118', 'MT224', 'MG223', 'EE229', 'CS219']
# Sarah R Young ['CS328', 'CS302', 'EE229', 'AI2011']
# Sarah Austin ['SS111', 'CS328', 'MG220', 'MT205', 'MG223']
# Ana B Javier Cuetos ['EE229', 'CS302', 'CS328', 'MG220', 'CS219']
# Naseem Akram ['EE229', 'CY2012', 'CS218', 'EE229']
# Yas Khaled ['CS219', 'MG220', 'CY2012', 'CS218']
# Salwa S Alobaid ['CY2012', 'AI2011', 'MG220', 'EE229']
# Natasha Lelijveld ['CS217', 'SS118', 'EE229', 'DS3011']
# Ann Wilson ['EE229', 'CS220', 'CS218', 'CS307']
# Ayman Jaheen ['MT205', 'CS328', 'SS111', 'EE229']
# Hamza Bin Muhammad ['AI2011', 'CS328', 'CS118', 'CS328', 'CY2012']
# Nosheen Maqbool ['MT205', 'EE229', 'SS111', 'CS118']
# Nadine Meyer ['CS118', 'CY2012', 'CS302', 'SS118']
# Bahjat Al-Ani ['CY2012', 'SS113', 'CS328', 'MG223']
# Kiran K Chahal ['MT205', 'CS328', 'SS113', 'EE229', 'AI2011']
# Adam Flowers ['DS3011', 'CS328', 'EE229', 'MT205']
# Aida Hoxha ['SS118', 'CS218', 'SS113', 'CS328']
# Adam Selby ['CS328', 'MG220', 'MT205', 'AI2011']
# Leyla Doroudi ['DS3011', 'MG223', 'MG220', 'CS307']
# Shireen Dowlut-Beebeejaun ['MG220', 'SE110', 'MT224', 'CS307']
# Jan Fiala ['CS217', 'CS218', 'SS118', 'CS118']
# Sam Dalgleish ['CS217', 'MT205', 'CS307', 'SS111']
# Nima Dirie ['SS113', 'MG223', 'CS220', 'SS111']
# Sarah Wilson ['DS3011', 'CS302', 'CS217', 'MT224']
# Sarah J Hammon ['MG220', 'CS302', 'CS211', 'CS328']
# Tina Nasersharif ['SE110', 'EE227', 'EE229', 'AI2011']
# Faraj B Shaban ['EE227', 'CS328', 'MG220', 'MT205']
# Zahra Faraji Rad ['MG220', 'CS219', 'CS118', 'MG223', 'SE110']
# Sarah Montgomery ['CS328', 'MG223', 'CS219', 'CS118']
# Omar Chaudhrey ['CS307', 'CS211', 'SS118', 'CS219']
# Shari K Rasmussen ['CS219', 'EE227', 'MT224', 'AI2011']
# Sadra Keyhani ['CS217', 'AI2011', 'CY2012', 'MT224']
# Marwa Elcheikh ['CS302', 'AI2011', 'MT224', 'SS111']
# Kamila Houdkova ['EE227', 'CS302', 'CS211', 'MT205']
# Irfan Yousaf ['SS152', 'CS211', 'EE229', 'SS111']
# Faris Quaid ['MT205', 'SE110', 'SS111', 'CS211']
# Sajida Ayub ['CY2012', 'MG223', 'CS328', 'AI2011']
# Yaser A Aljammaz ['MT224', 'CS219', 'EE227', 'AI2011']
# Amber Summerfield ['EE229', 'AI2011', 'CS219', 'EE227']
# Anita Hodler ['MG220', 'EE227', 'EE229', 'CS302']
# Eileen Haycox ['MG220', 'CS307', 'AI2011', 'CS218']
# Zeenat K Guness-Goolbar ['CS211', 'CS211', 'CS302', 'EE227']
# Nausheen Saleem ['CS328', 'CS218', 'CS211', 'CS220']
# Farzana Yamin ['CS328', 'CY2012', 'CS118', 'CS220']
# Mohammed Z Albahar ['AI2011', 'MT205', 'EE227', 'CS211']
# Dalia Remeikyte ['SS152', 'CS302', 'CS217', 'MG220']
# Arsheen Rajpar ['CY2012', 'CS211', 'CS211', 'CS302']
# Sarah Clements ['CS218', 'CS302', 'EE227', 'CS328']
# Samina Akbar ['CS328', 'CS118', 'CS220', 'CS307']
# Sarah E Kirkham-Slack ['CS302', 'CS118', 'SS111', 'SS152']
# Sarah J Bradford ['CS328', 'SS113', 'SS118', 'EE229']
# Mona Vadher ['EE227', 'SS113', 'CY2012', 'EE229']
# Aidan P Murphy ['EE227', 'CS217', 'CS328', 'SS111']
# Ahmed Abbas Ahmed ['MT205', 'SS113', 'CS307', 'CY2012']
# Ayse Hatunoglu ['DS3011', 'EE229', 'MG223', 'CS220']
# Siraj Shariff ['EE227', 'CS211', 'SS111', 'CS118']
# Damian A Cummings ['CS307', 'SE110', 'SS118', 'CS217']
# Asim Ali ['CS220', 'CS211', 'CS211', 'DS3011']
# Leila C Payne ['MG223', 'AI2011', 'CS118', 'CS211']
# Sarah L Barber-Jones ['DS3011', 'EE229', 'AI2011', 'CS219']
# Hazimah H Hj Hamzah ['CS218', 'SS113', 'CS211', 'MG223']
# Babak Cheraghchi Bashi Astaneh ['EE227', 'CS328', 'SS113', 'SS111']
# Rafal Szczypinski ['CY2012', 'EE229', 'MG223', 'SS111']
# Shahina Parveen ['CS307', 'CS218', 'MT224', 'CY2012']
# Zainab Khattak ['EE229', 'SS118', 'CS118', 'CS220']
# Iram Meharban ['SS152', 'CS328', 'MG220', 'MG223']
# Maryam Askari Louyeh ['CS118', 'SS113', 'EE229', 'CS218']
# Tara Glickman ['DS3011', 'MT205', 'CS211', 'SS111']
# Faheema Korumtollee ['CS220', 'CY2012', 'MG223', 'CS328']
# Salman Hassan Zadeh ['MT205', 'EE229', 'CS118', 'AI2011']
# Sarah Hanley ['MT224', 'SS118', 'SS113', 'MG220']
# Adam Sanders ['MT205', 'MG223', 'AI2011', 'CS328']
# Leanne M Taylor-Smith ['SS152', 'MG220', 'CS328', 'CS211']
# Ibrar Manawer ['DS3011', 'CS220', 'CS211', 'EE227']
# Soha Siahpoosh Kolyaei ['EE227', 'CS219', 'EE229', 'SS113']
# Adam Green ['MG220', 'AI2011', 'CS217', 'DS3011']
# Syed M Ghufran ['SS113', 'DS3011', 'CS218', 'CS217']
# Lilia Kyuchukova ['MT224', 'EE229', 'AI2011', 'EE229']
# Sam Duncanson ['MT205', 'MG220', 'EE229', 'DS3011']
# Negar Saleh ['CS328', 'CY2012', 'CS307', 'MT224']
# Sarah Hewitt ['SS113', 'CS219', 'CY2012', 'CS328']
# Yasir M Salih ['CS307', 'AI2011', 'MG223', 'EE227']
# Mohammed Azam ['CS211', 'CY2012', 'SS111', 'CS307', 'MG220']
# Huda O Ali ['SS113', 'CS211', 'SE110', 'SS118']
# Sagar R Jilka ['EE229', 'CS328', 'AI2011', 'SS152']
# Samar E Nassar ['CS218', 'CS211', 'SE110', 'EE229']
# Syed M Abbas ['CS328', 'CS219', 'CS218', 'SS118']
# Shahzada S Niwaz ['MT224', 'CS217', 'CS328', 'SS111']
# Ali M Sadeghioon ['DS3011', 'CY2012', 'CS211', 'MT224']
# Arman N Bahadori ['CS328', 'CY2012', 'CS211', 'AI2011']
# Sarina Patel ['CS217', 'AI2011', 'MT205', 'CS302']
# Sam J Pottier ['DS3011', 'CS328', 'CS118', 'SE110']
# Razan Z Haji Zulkifli ['CS302', 'CS211', 'CS328', 'MG220']
# Shadan Alam ['CS211', 'SS152', 'SE110', 'MT224']
# Kamila Keshubay ['AI2011', 'CS118', 'EE227', 'MG220']
# Anja Sarlah ['EE229', 'CS217', 'CS302', 'MG220']
# Farzad Farahmand ['SS152', 'CS217', 'CS211', 'CS220']
# Salma Khanam ['DS3011', 'MG223', 'SE110', 'CS302']
# Natasha Tait ['CS220', 'CS211', 'EE227', 'SS118', 'SS111']
# Zaki Choudhury ['MT205', 'MT224', 'CS218', 'DS3011']
# Ibrahim Adegboye ['MG220', 'CS328', 'MG223', 'MT224']
# Mohammed Zafran ['EE229', 'EE229', 'MT205', 'CS218']
# Kabir A Khan ['SS118', 'CS328', 'DS3011', 'SE110']
# Adam Kirk ['CS218', 'MT205', 'SS111', 'DS3011']
# Maysa Saeidi ['CS307', 'SS118', 'EE229', 'MT224']
# Zahir Hussain ['EE227', 'SS118', 'CS307', 'CS118', 'MT224']
# Dean Brodesky ['CS307', 'CS218', 'SS118', 'CS328']
# Nina N Wronka ['DS3011', 'AI2011', 'SE110', 'CS218']
# Imtiaz Kermali ['MT224', 'CS218', 'CS302', 'CS307']
# Judi Glen ['CS219', 'EE229', 'EE229', 'SE110']
# Hassana Begum ['CS302', 'EE229', 'MG223', 'SS113']
# Ahmed Ahmed ['CS219', 'CS307', 'MT224', 'CS217']
# Mohammed Sukkari ['MG220', 'CS217', 'CS302', 'EE229']
# Sam Isherwood ['CS211', 'MT224', 'SS111', 'CS328']
# Sarah French ['CS118', 'CS302', 'DS3011', 'EE229']
# Bibi A Khan ['EE229', 'SS113', 'MG220', 'CS218']
# Sarwar Hussain ['CS211', 'CS217', 'CY2012', 'CS219']
# Adam C Ryan ['CS118', 'MG220', 'CS217', 'DS3011']
# Halima Sayed ['CS211', 'MG220', 'SS152', 'CS220']
# Sarah Dobson ['SS113', 'MT224', 'CS118', 'CS328']
# Sarah Taylor ['CS118', 'SS113', 'MT205', 'MT224']
# Aleena Unadkat ['MT205', 'MG223', 'CS211', 'CS211']
# Eileen Harris ['MG220', 'CS218', 'MT224', 'CS211']
# Saleem Abubacker ['EE227', 'MG220', 'EE229', 'SS152']
# Shadan Mirarmandehi ['CS118', 'AI2011', 'SE110', 'CY2012']
# Ana Sbert Ortin ['SS118', 'SS111', 'MT224', 'SS152']
# Sarah Fogg ['CS302', 'DS3011', 'CS218', 'CS217']
# Sarah Hadley ['MG223', 'MG220', 'CS217', 'CS328']
# Jina Zhao ['MT205', 'DS3011', 'CS307', 'MG220']
# Sarah S Shahid ['CS328', 'SS111', 'MT205', 'EE229', 'DS3011']
# Nadia Parveen ['CS219', 'CY2012', 'SS111', 'CS211']
# Natasha Edwards ['CS220', 'AI2011', 'CS219', 'MG223', 'MT224']
# Aras Panahian Jand ['EE229', 'SS113', 'CS220', 'SS111', 'MT205']
# Sara De La Serna ['MT224', 'CS302', 'EE229', 'EE227']
# Ayda Niazi ['SS152', 'DS3011', 'MT224', 'EE227']
# Selina V Penarski ['CS211', 'EE229', 'SS113', 'SE110']
# Naveed Hussain ['CS218', 'EE229', 'AI2011', 'CS211']
# Sonia V Diaz ['CS118', 'SE110', 'EE229', 'CS328', 'MG220']
# Ann White ['SS118', 'EE227', 'CS218', 'SS113']
# Maria Antonia Morua Leyva ['SS113', 'AI2011', 'CS328', 'DS3011']
# Meryem Mehmetbasoglu ['CS218', 'CS118', 'EE229', 'EE229']
# Shahid Khan ['CS302', 'CS307', 'CS217', 'MG223']
# Omar S Aslam ['CS211', 'EE229', 'SS113', 'AI2011']
# Manal Aldaihani ['MG220', 'SS118', 'CS328', 'CS211']
# Ameerah Kasenally-Boodoo ['DS3011', 'EE229', 'SS118', 'CS307']
# Meltem Naylor ['CS211', 'EE229', 'CS218', 'CS219']
# Sadia Rehman ['MT205', 'EE229', 'CS220', 'CS307']
# Omar F Khan ['EE229', 'MG223', 'SS113', 'MT205']
# Sonia Zain ['MG223', 'AI2011', 'MT224', 'CS211']
# Behzad Babakhani ['CS307', 'CS218', 'CS219', 'AI2011']
# Rida Shaikh ['SS111', 'CS220', 'SS152', 'CY2012']
# Sarah L Clark ['CS211', 'MT205', 'MG220', 'SS118']
# Amir Ahmed ['SS118', 'CS328', 'CS307', 'SE110', 'SS152']
# Ann D Brix ['AI2011', 'SS111', 'CS218', 'SS152']
# Ann Tai ['AI2011', 'MT224', 'CS211', 'CY2012']
# Mohamed F Bakaram ['CS219', 'EE229', 'AI2011', 'DS3011']
# Sarah H Przybylak ['SS118', 'CS307', 'MG220', 'CS211']
# Natasha J Seaward ['CS217', 'SE110', 'MG223', 'AI2011']
# Seema Mandalia ['CS217', 'MT205', 'SS152', 'CS328']
# Jasmine Winyard ['CS220', 'DS3011', 'CS211', 'MT224']

# %% [markdown]
# Generating population randomly.

# %%
#Generating a population of size 'popSize' randomly.
def generatePopulation(crs, tch, popSize):  
    population = []
    num_exams = len(crs)
    for j in range(popSize):
      courses = []
      teachers = []
      timeslots = []
      courses = copy.deepcopy(crs)
      teachers = copy.deepcopy(tch)
      timeslots = slots
      days = week
      chromosome = []
      for i in range(num_exams):
        course = random.choice(courses)
        teacher = random.choice(teachers)
        day = random.choice(days)
        slot = random.choice(slots)
        classroom = random.choice(classrooms)
        chromosome.append(course.course_code)
        chromosome.append(teacher.teacher_name)
        chromosome.append(day)
        chromosome.append(slot)
        chromosome.append(classroom)
        courses.remove(course)
        teachers.remove(teacher)
      population.append(chromosome)  
    return population

# %% [markdown]
# # Hard Constraints

# %% [markdown]
# Finding the papers which have been set at a specific time and date.

# %%
def getPaperClashes(timetable):
    index = 0
    paper_clashes = dict()
    for data in timetable:
      if index == 0: #Course Code.
        course_code = data
      elif index == 1: #Teacher Name.
        teacher_name = data
      elif index == 2: #Day.
        day = data
      elif index == 3: #Time slot.
        time_slot = data
      elif index == 4: #Room.
        room = data
        # print("Current Line : ", course_code, teacher_name, day, time_slot, room)
        timeslot = Timeslot(day,time_slot)
        if timeslot not in paper_clashes.keys():
          paper_clashes[timeslot] = []
          paper_clashes[timeslot].append(course_code)
          # print("Adding new entry :" , (time_slot,day), course_code)
        else:
          paper_clashes[timeslot].append(course_code)
          # print("Adding to existing.", (time_slot,day), course_code)
        index = 0
        continue
      index = index + 1
    return paper_clashes

#Testing function.    
testpopulation = generatePopulation(courses,teachers,20)
test_paper_clashes = getPaperClashes(testpopulation[0])
for key,value in test_paper_clashes.items():
  print(key.day,key.time,value)
# Out:
# Friday-1 9:00-12:00 ['EE227', 'CS220', 'CS217']
# Tuesday-1 9:00-12:00 ['MG223']
# Monday-1 9:00-12:00 ['MT224', 'SE110']
# Friday-1 2:00-5:00 ['CS302', 'AI2011', 'MG220', 'CY2012']
# Thursday-1 2:00-5:00 ['EE229', 'CS211', 'CS118']
# Thursday-2 2:00-5:00 ['SS113', 'CS219', 'CS307']
# Tuesday-1 2:00-5:00 ['SS118', 'CS328']
# Friday-2 2:00-5:00 ['CS218']
# Wednesday-1 9:00-12:00 ['MT205']
# Monday-1 2:00-5:00 ['SS111']
# Monday-2 9:00-12:00 ['DS3011']
# Wednesday-2 2:00-5:00 ['SS152']

# %% [markdown]
# Calculating the number of students from a timetable which have clashing papers and returning the count.

# %%
#Utility function to find intersection of two lists.
def intersection(list1, list2):
    intersecting_values = [value for value in list1 if value in list2]
    return intersecting_values

def calculateClashes(paper_clashes,student_registrations):
  numClashes = 0
  students_list = dict()
  for key,value in paper_clashes.items():
    if len(value) >= 2: # Atleast two subjects in the same slot.
      for course in value:
        students_list[course] = []
        for student_name,subjects in student_registrations.items():
          if course in subjects:
            students_list[course].append(student_name)

  for key,value in paper_clashes.items():
    if len(value) >= 2:
      for i in range(len(value)):
        list1 = students_list[value[i]]
        for j in range(i+1,len(value)):
          list2 = students_list[value[j]]
          if len(intersection(list1,list2)) > 0:
            # print("Clashes between ", value[i], "and ", value[j] ," are : ", len(intersection(list1,list2)) )
            numClashes = numClashes + len(intersection(list1,list2))
            # print("Clashes of ", value[i], " and " , value[j], " : ", intersection(list1,list2))
  # print("Total clashes found of : ", numClashes , " students.")
  return numClashes
#Testing function.
calculateClashes(test_paper_clashes,student_registrations)
# Out:
# 78

# %% [markdown]
# Finding those teachers which have been assigned to specific day and time.

# %%
#Find teachers who are invigilating multiple exams at the same day and time.
def getTeacherClashes(timetable):
  index = 0
  teacher_clashes = dict()
  for data in timetable:
    if index == 0: #Course Code.
      course_code = data
    elif index == 1: #Teacher Name.
      teacher_name = data
    elif index == 2: #Day.
      day = data
    elif index == 3: #Time slot.
      time_slot = data
    elif index == 4: #Room.
      room = data
      # print("Current Line : ", course_code, teacher_name, day, time_slot, room)
      timeslot = Timeslot(day,time_slot)
      if timeslot not in teacher_clashes.keys():
        teacher_clashes[timeslot] = []
        teacher_clashes[timeslot].append(teacher_name)
        # print("Adding new entry :" , (time_slot,day), teacher_name)
      else:
        teacher_clashes[timeslot].append(teacher_name)
        # print("Adding to existing.", (time_slot,day), teacher_name)
      index = 0
      continue
    index = index + 1
  return teacher_clashes

#Testing function.
test_teacher_clashes = getTeacherClashes(testpopulation[0])
for key,value in test_teacher_clashes.items():
  print(key.day,key.time,value)
# Out:
# Friday-1 9:00-12:00 ['Muhammad Asim', 'Amna Irum', 'Shams Farooq']
# Tuesday-1 9:00-12:00 ['Nagina Safdar']
# Monday-1 9:00-12:00 ['Zainab Abaid', 'Zeeshan Qaiser']
# Friday-1 2:00-5:00 ['Sidra Khalid', 'Farah Jabeen Awan', 'Asma Nisa', 'Noreen Jamil']
# Thursday-1 2:00-5:00 ['Sehrish Hassan', 'Mehwish Hassan', 'Irum Inayat']
# Thursday-2 2:00-5:00 ['Usman Rashid', 'Sara Aziz', 'Shafaq Riaz']
# Tuesday-1 2:00-5:00 ['Zainab Moin', 'Hammad Majeed']
# Friday-2 2:00-5:00 ['Rohail Gulbaz']
# Wednesday-1 9:00-12:00 ['Sanaa Ilyas']
# Monday-1 2:00-5:00 ['Farah Naz']
# Monday-2 9:00-12:00 ['Shahzad Mehmood']
# Wednesday-2 2:00-5:00 ['Sumera Abbas']

# %% [markdown]
# Returns number of teachers which are invigilating more than one course at the same time.

# %%
def calculateTeacherClashes(teacher_clashes):
  numClashes = 0
  for key,value in teacher_clashes.items():
    if len(value) >= 2:
      numClashes = numClashes + len([item for item, count in collections.Counter(value).items() if count > 1])
  # print("Total clashes found of : ", numClashes , " teachers.")
  return numClashes
#Testing Function.
calculateTeacherClashes(test_teacher_clashes)
# Out:
# 0

# %% [markdown]
# Finds the number of teachers who are invigilating back to back (consecutive) exams on the same day.

# %%
#Find teachers who are invigilating consecutive exams.
def getConsecutiveTeacherClashes(teacher_clashes):
  numClashes = 0
  for day1 in teacher_clashes.keys():
    checkDays = False
    for day2 in teacher_clashes.keys():
      if day1 == day2:
        checkDays = True
        continue
      if checkDays == True:
        #Check if day same and timeslot different and teacher repeating.
        if day1.day == day2.day:
          # print("Checking days : ", day1.day, day1.time, " and ", day2.day, day2.time)
          list1 = teacher_clashes[day1]
          list2 = teacher_clashes[day2]
          if len(intersection(list1,list2)) > 0:
            # print("Teacher clashes found for day: ", day1.day, " Timings : ", day1.time, " " ,day2.time)
            # print(list1)
            # print(list2)
            numClashes = numClashes + len(intersection(list1,list2))
          # else:
          #   print("No teacher clashes found!")
  return numClashes
                      

getConsecutiveTeacherClashes(test_teacher_clashes)
# Out:
# 0

# %% [markdown]
# Find the classrooms which have been assigned to courses at a specific day and time.

# %%
def getClassroomClashes(timetable):
  index = 0
  classroom_clashes = dict()
  for data in timetable:
    if index == 0: #Course Code.
      course_code = data
    elif index == 1: #Teacher Name.
      teacher_name = data
    elif index == 2: #Day.
      day = data
    elif index == 3: #Time slot.
      time_slot = data
    elif index == 4: #Room.
      room = data
      # print("Current Line : ", course_code, teacher_name, day, time_slot, room)
      timeslot = Timeslot(day,time_slot)
      if timeslot not in classroom_clashes.keys():
        classroom_clashes[timeslot] = []
        classroom_clashes[timeslot].append(room)
        # print("Adding new entry :" , (time_slot,day), teacher_name)
      else:
        classroom_clashes[timeslot].append(room)
        # print("Adding to existing.", (time_slot,day), teacher_name)
      index = 0
      continue
    index = index + 1
  return classroom_clashes
#Testing function.
test_classroom_clashes = getClassroomClashes(testpopulation[0])
for key,value in test_classroom_clashes.items():
  print(key.day,key.time,value)
# Out:
# Friday-1 9:00-12:00 ['C-302', 'C-301', 'C-301']
# Tuesday-1 9:00-12:00 ['C-309']
# Monday-1 9:00-12:00 ['C-301', 'C-310']
# Friday-1 2:00-5:00 ['C-305', 'C-303', 'C-310', 'C-307']
# Thursday-1 2:00-5:00 ['C-303', 'C-309', 'C-305']
# Thursday-2 2:00-5:00 ['C-303', 'C-302', 'C-309']
# Tuesday-1 2:00-5:00 ['C-308', 'C-302']
# Friday-2 2:00-5:00 ['C-304']
# Wednesday-1 9:00-12:00 ['C-302']
# Monday-1 2:00-5:00 ['C-304']
# Monday-2 9:00-12:00 ['C-301']
# Wednesday-2 2:00-5:00 ['C-308']

# %% [markdown]
# Find the number of classrooms which have been assigned to multiple courses at the same day and time, i.e. one classroom has been assigned to two or more courses at the same day and time.

# %%
def calculateClassroomClashes(classroom_clashes):
  numClashes = 0
  for key,value in classroom_clashes.items():
    if len(value) >= 2:
      numClashes = numClashes + len([item for item, count in collections.Counter(value).items() if count > 1])
  # print("Total clashes found of : ", numClashes , " classrooms.")
  return numClashes
#Testing function.
calculateClassroomClashes(test_classroom_clashes)
# Out:
# 1

# %% [markdown]
# # Soft Constraints

# %% [markdown]
# Find the number of students appearing in consecutive papers on the same day.

# %%
def calculateConsecutivePaperClashes(paper_clashes,student_registrations):
  numClashes = 0
  students_list = dict()
  daysChecked = []
  for key,value in paper_clashes.items():
    for course in value:
      students_list[course] = []
      for student_name, subjects in student_registrations.items():
        if course in subjects:
          students_list[course].append(student_name)

  
  for key1,value1 in paper_clashes.items():
    for key2,value2 in paper_clashes.items():
      if key1.day == key2.day: #Same day.
        if key1.time != key2.time: #Different times.
          if key1.day not in daysChecked:
            daysChecked.append(key1.day)
            for i in range(len(value1)):
              list1 = students_list[value1[i]]
              for j in range(len(value2)):
                list2 = students_list[value2[j]]
                if len(intersection(list1,list2)) > 0:
                  # print("Consecutive clashes between", value1[i], " and ", value2[j], " are: ", len(intersection(list1,list2)))
                  numClashes = numClashes + len(intersection(list1,list2))
                # print("Consecutive Clashes of ", value1[i], " and " , value2[j], " : ", intersection(list1,list2))
  # print("Total consecutive clashes found of : ", numClashes , " students.")
  return numClashes
#Testing function.
calculateConsecutivePaperClashes(test_paper_clashes,student_registrations)
# Out:
# 66

# %% [markdown]
# Finds the number of students who are appearing in both CS and Management courses, and have their CS course scheduled before their management course.

# %%
def calculateManagementCScourseClashes(paper_clashes,student_registrations):
  numClashes = 0
  students_list = dict()
  sorted_paper_clashes = dict()
  daysChecked = []
  for key,value in paper_clashes.items():
    for course in value:
      students_list[course] = []
      for student_name, subjects in student_registrations.items():
        if course in subjects:
          students_list[course].append(student_name)

  for day in week:
    for slot in slots:
      for key,value in paper_clashes.items():
        if key.day == day and key.time == slot:
          sorted_paper_clashes[key] = value

  # for key,value in sorted_paper_clashes.items():
    # print(key.day,key.time,value)
    
  for key,value in sorted_paper_clashes.items():
    for course in value:
      if course[0] == 'C' and course[1] == 'S':#Choose a CS course.
        csCourse = course
        # print("Checking if any Management course after ", csCourse)
        checkDays = False
        for key2,value2 in sorted_paper_clashes.items():
          if key == key2:
            checkDays = True
            continue
          if checkDays == True:
            for course2 in value2:
              if course2[0] == 'M' and course2[1] =='G':#Found an MG course.
                mgCourse = course2
                list1 = students_list[csCourse]
                list2 = students_list[mgCourse]
                # print("Management course found! Checking courses ", csCourse , " and ", mgCourse)
                # print(print("Students taking both of these courses are : ", len(intersection(list1,list2))))
                if len(intersection(list1,list2)) > 0:
                  # print("CS Course ", csCourse , " was scheduled before MG Course ", mgCourse, " and " , len(intersection(list1,list2)) ," clashes were found!!!!!")
                  numClashes += len(intersection(list1,list2))
  return numClashes
  
calculateManagementCScourseClashes(test_paper_clashes,student_registrations)
# Out:
# 36

# %% [markdown]
# Implements crossover between two parents and returns new child.

# %%
def crossover(p_1, p_2):
  child = []
  random_1 = [*range(0,23,1)]
  random_2 = [*range(0,23,1)]
  for i in range(23):
    index = random.choice(random_1)
    random_1.remove(index)
    index = index * 5
    exam = p_1[index:index+5]
    if exam[0] not in child:
      child.extend(exam)

    if len(child) == 115:
      break
    
    index = random.choice(random_2)
    random_2.remove(index)
    index = index * 5
    exam = p_2[index:index+5]
    if exam[0] not in child:
      child.extend(exam)

  # assert(len(child)==115)
  return child

# %% [markdown]
# Implements mutation on child with a probability, and returns newly mutated child.

# %%
def mutation(child, teachers, courses, slots, week, classrooms):
  mychild = copy.deepcopy(child)
  prob = [*range(0,101,1)]
  for count, val in enumerate(child):
    chance = random.choice(prob)
    if chance <= 4:
      n = count%5
      if n == 0:
        continue
      elif n == 1:
        teacher = random.choice(teachers)
        mychild[count] = teacher.teacher_name
      elif n == 2:
        day = random.choice(week)
        mychild[count] = day
      elif n == 3:
        slot = random.choice(slots)
        mychild[count] = slot
      elif n == 4:
        room = random.choice(classrooms)
        mychild[count] = room
  return mychild

# %% [markdown]
# Finds fitness of a timetable depending on hard and soft constraints.

# %%
def calculateFitness(timetable):
  fitness = 0

  paper_clashes = dict()
  teacher_clashes = dict()
  classroom_clashes = dict()
  paper_clashes = getPaperClashes(timetable)
  teacher_clashes = getTeacherClashes(timetable)
  classroom_clashes = getClassroomClashes(timetable)

  studentsClashes = 0
  teachersClashes = 0
  consecutiveTeachersClashes = 0
  roomClashes = 0
  studentsClashes = calculateClashes(paper_clashes,student_registrations)
  teachersClashes = calculateTeacherClashes(teacher_clashes)
  consecutiveTeachersClashes = getConsecutiveTeacherClashes(teacher_clashes)
  roomClashes = calculateClassroomClashes(classroom_clashes)

   
  softClashes = calculateConsecutivePaperClashes(paper_clashes,student_registrations) + calculateManagementCScourseClashes(paper_clashes,student_registrations)
  hardClashes = studentsClashes + teachersClashes + consecutiveTeachersClashes + roomClashes
  clashes = hardClashes  + (softClashes / 10)
  if clashes == 0.0:
    print("All constraints (soft + hard) met!")
    fitness = 10000000
    return fitness
  if hardClashes == 0:
    print("All hard constraints met! Returning timetable...")
    print("Remaining soft clashes : ", softClashes)
    fitness = 10000000
    return fitness 
  fitness = (1000 / (clashes*clashes)) 
  return fitness

def getParentByRelativeFitness(matingPool):
  return random.choices(list(matingPool.keys()),weights=list(matingPool.values()),k=2)

# %% [markdown]
# Genetic Algorithm implementation.

# %%
population = []
def geneticAlgorithm(population):
  #Initialization.
  populationSize = 100
  population = generatePopulation(courses,teachers,populationSize)
  iteration = 0
  #Start of Algorithm.
  while True:
    #Evaluating fitness of each element of population.
    matingPool = dict()
    for timetable in population:
      fitness = calculateFitness(timetable)
      if (fitness == 10000000):
        # print("Fitness == ",fitness)
        return timetable
      matingPool[tuple(timetable)] = fitness
    print("Iteration ",iteration, ": [", end=" ")
    sortedPool = {k: v for k,v in sorted(matingPool.items(),key=lambda item: item[1],reverse=True)}
    for key,value in sortedPool.items():
      print(value, end=", ")
    print(" ]", end= " ")
    print()
    iteration = iteration + 1
    #Reproduction phase.
    newPopulation = []
    for i in range(populationSize):
      #Selecting two parents based on relative fitness.
      parents = getParentByRelativeFitness(matingPool)
      crossoverChild = crossover(list(parents[0]),list(parents[1]))
      mutatedChild = mutation(crossoverChild, teachers, courses, slots, week, classrooms)
      newPopulation.append(mutatedChild)
    population = newPopulation
idealTimetable = geneticAlgorithm(population)
# Out:
# Iteration  0 : [ 0.43766740778347724, 0.4340277777777778, 0.41649312786339027, 0.40647762747138394, 0.38750077500155, 0.3741268813905547, 0.3684041835979089, 0.35870064279155195, 0.3467779130211638, 0.3354398958794563, 0.31548826541396796, 0.31105263321606647, 0.3067098923141568, 0.2993259180325906, 0.29522561141224124, 0.29320698067179585, 0.29320698067179585, 0.2922054204105486, 0.2912089832147142, 0.289231338794021, 0.289231338794021, 0.2796389302133086, 0.2678659920015215, 0.2678659920015215, 0.26525480376449617, 0.2593085278795563, 0.2543694308992722, 0.2527543909756572, 0.248000496000992, 0.248000496000992, 0.24337946996819032, 0.2381496723060509, 0.23668639053254437, 0.2352365538785803, 0.22410269281795692, 0.2227667631989307, 0.22210327358014936, 0.21882987290360986, 0.2124964938078522, 0.2082253164504247, 0.20234354291403034, 0.2011971228811428, 0.20006041824631035, 0.19893331954062315, 0.1972604469132685, 0.19615689413020107, 0.19560858721697882, 0.19397738999542213, 0.19290123456790123, 0.18868494143219422, 0.18816764231589206, 0.1856127820386223, 0.1836061721050815, 0.18017206432142696, 0.1782528016884105, 0.17777777777777778, 0.17589654468827612, 0.17543090215341434, 0.17496710618403744, 0.1745051470293116, 0.1740450150026803, 0.1731301939058172, 0.16998448041693792, 0.16822527382868951, 0.16735589402355366, 0.1656372312742969, 0.159020687001172, 0.1566413586444883, 0.1531712577198314, 0.15204015076301353, 0.15166589822611565, 0.15055139448229138, 0.15018262206843522, 0.14981520294716466, 0.14835892772101403, 0.1479981766624635, 0.14692378328741965, 0.14656825097174753, 0.14071644370146164, 0.13743645282012731, 0.1352082206598161, 0.1345815321838276, 0.13395919067215362, 0.13031421363190926, 0.12913223140495866, 0.12767723195761116, 0.12400732139225501, 0.12263784186831395, 0.12209639510393455, 0.1161192033293698, 0.11414274234787057, 0.10918830505902175, 0.10369958644604925, 0.09822401164543881, 0.0978357748250941, 0.09104947264145447, 0.0901868581514039, 0.08573388203017833, 0.07574604170122579, 0.04140930781857422,  ]
767, 1.6935087808430287, 1.6935087808430287, 1.6391024275106953, 1.6391024275106953, 1.6259105098855358, 1.587276392438215, 1.5747039556563367, 1.562280304332203, 1.5023135628868458, 1.4792899408284024, 1.46797610134907, 1.4567915622632714, 1.4348025711662078, 1.4133077053536094, 1.392292269993317, 1.312749422390254, 1.312749422390254, 1.312749422390254, 1.3032881961188079, 1.2755102040816326, 1.2574820180071424, 1.2486109203511093, 1.2225536701061177, 1.2140489747356409, 1.156925355176084, 1.1037405768148254, 1.0892178326743565, 1.0610192150579847, 1.0473287879263937, 1.027284681130835, 1.0078105316200554, 1.00144207659029, 0.964468963388758, 0.9351999925183999, 0.9295062462819751, 0.9295062462819751, 0.9238643397603498, 0.8753194916144394, 0.8499859752314088, 0.830502703286299, 0.7846275765208043, 0.7673360394717659, 0.7673360394717659, 0.7547397657287769, 0.7149189281935429, 0.7073336351290176, 0.6998684247361497, 0.6925207756232687, 0.6852882322304761, 0.6781684027777778, 0.6711589572874439, 0.6507705122865471, 0.6157294238619783, 0.5862730038869901, 0.5588808968920634, 0.5536332179930796, 0.5408328826392644, 0.5072640207775343, 0.4916396674549289, 0.4565709693914823, 0.4565709693914823, 0.4526935264825713, 0.42865287261722584, 0.4268834096031692, 0.4233771952107572, 0.4131138872364333, 0.40977560687767384, 0.40647762747138394, 0.4, 0.389030885161973, 0.38750077500155, 0.37557839072171145, 0.3741268813905547, 0.37124899298710656, 0.3600632271026792, 0.35734577849564575, 0.32116750812553796, 0.28630243271177075, 0.2768541615333291,  ]
# All hard constraints met! Returning timetable...
# Remaining soft clashes :  48

# %%
def printSolution(timetable):
  fitness = 0

  paper_clashes = dict()
  teacher_clashes = dict()
  classroom_clashes = dict()
  paper_clashes = getPaperClashes(timetable)
  teacher_clashes = getTeacherClashes(timetable)
  classroom_clashes = getClassroomClashes(timetable)

  studentsClashes = 0
  teachersClashes = 0
  consecutiveTeachersClashes = 0
  roomClashes = 0
  studentsClashes = calculateClashes(paper_clashes,student_registrations)
  teachersClashes = calculateTeacherClashes(teacher_clashes)
  consecutiveTeachersClashes = getConsecutiveTeacherClashes(teacher_clashes)
  roomClashes = calculateClassroomClashes(classroom_clashes)

    
  softClashes = calculateConsecutivePaperClashes(paper_clashes,student_registrations) + calculateManagementCScourseClashes(paper_clashes,student_registrations)
  hardClashes = studentsClashes + teachersClashes + consecutiveTeachersClashes + roomClashes
  clashes = hardClashes  + (softClashes / 10)
  print("Hard Constraints Satisfied :")
  print("->Exam scheduled for each course and each student is enrolled in at least 3 courses.")
  if studentsClashes == 0:
    print("->All students clashes resolved.")
  if teachersClashes == 0:
    print("->All teachers clashes resolved.")
  if consecutiveTeachersClashes == 0:
    print("->No teacher invigilates consecutive papers.")
  print("->All papers held between 9am and 5pm. Each exam is invigilated by a teacher. Exam is not held on weekend.")

  print()
  print("Following soft constraints have been optimized as much as possible:")
  if calculateConsecutivePaperClashes(paper_clashes,student_registrations) == 0:
    print("->No consecutive papers scheduled for any student.")
  else:
    print("->Student appearing in more than 1 exam consecutively.")
  if calculateManagementCScourseClashes(paper_clashes,student_registrations) == 0:
    print("->No management course is scheduled before CS course for a student who takes both.")
  else:
    print("->Management course is scheduled before CS course for a student who is enrolled in both.")

printSolution(idealTimetable)
# Out:
# Hard Constraints Satisfied :
# ->Exam scheduled for each course and each student is enrolled in at least 3 courses.
# ->All students clashes resolved.
# ->All teachers clashes resolved.
# ->No teacher invigilates consecutive papers.
# ->All papers held between 9am and 5pm. Each exam is invigilated by a teacher. Exam is not held on weekend.
#
# Following soft constraints have been optimized as much as possible:
# ->Student appearing in more than 1 exam consecutively.
# ->Management course is scheduled before CS course for a student who is enrolled in both.

# %%
courses_assigned = []
teachers_assigned = []
days_assigned = []
time_slots_assigned = []
rooms_assigned = []
index = 0 
for data in idealTimetable:
  if index == 0: #Course Code.
    courses_assigned.append(data)
  elif index == 1: #Teacher Name.
    teachers_assigned.append(data)
  elif index == 2: #Day.
    days_assigned.append(data)
  elif index == 3: #Time slot.
    time_slots_assigned.append(data)
  elif index == 4: #Room.
    rooms_assigned.append(data)
    index = 0
    continue
  index = index + 1
schedule = {'Course': courses_assigned,
            'Teacher': teachers_assigned,
            'Day': days_assigned,
            'Time-Slot': time_slots_assigned,
            'Venue':rooms_assigned,
            }
solution = pd.DataFrame(schedule)
print(solution)
# Out:
#     Course             Teacher          Day   Time-Slot  Venue
# 0    CS328    Shehreyar Rashid  Wednesday-2  9:00-12:00  C-310
# 1    EE229       Hasan Mujtaba     Friday-2   2:00-5:00  C-306
# 2    MG223      Behjat Zuhaira     Monday-1  9:00-12:00  C-304
# 3    CS219        Usman Rashid     Monday-1   2:00-5:00  C-304
# 4    MG220      Mehwish Hassan    Tuesday-1   2:00-5:00  C-308
# 5    CS211        Noreen Jamil   Thursday-1  9:00-12:00  C-308
# 6    CS302        Usman Rashid     Monday-2  9:00-12:00  C-307
# 7    EE227  Muhammad bin Qasim     Friday-1  9:00-12:00  C-308
# 8    CS118         Irum Inayat   Thursday-1   2:00-5:00  C-309
# 9    MT205        Arshad Islam    Tuesday-2  9:00-12:00  C-305
# 10   CS218           Amna Irum  Wednesday-1  9:00-12:00  C-303
# 11   SE110           Asma Nisa  Wednesday-1   2:00-5:00  C-307
# 12  AI2011  Muhammad bin Qasim    Tuesday-2   2:00-5:00  C-301
# 13   MT224         Gul e Aisha     Friday-2  9:00-12:00  C-310
# 14   CS220      Hassan Mustafa     Monday-2  9:00-12:00  C-308
# 15  DS3011           Farah Naz  Wednesday-2   2:00-5:00  C-307
# 16   SS118      Tayyaba Zainab    Tuesday-2   2:00-5:00  C-308
# 17   CS307        Mehboobullah   Thursday-2  9:00-12:00  C-306
# 18   CS217         Adnan Tariq     Friday-1   2:00-5:00  C-304
# 19   SS152         Adnan Tariq     Monday-1   2:00-5:00  C-302
# 20   SS111           Amna Irum   Thursday-2   2:00-5:00  C-309
# 21   SS113      Hassan Mustafa    Tuesday-1  9:00-12:00  C-306
# 22  CY2012         Ayesha Bano     Monday-2   2:00-5:00  C-307
